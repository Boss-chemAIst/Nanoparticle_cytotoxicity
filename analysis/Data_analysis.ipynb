# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir('C:/projects/laboratory/Nanoparticle_cytotoxicity/databases')

# %%
db = pd.read_csv('Tox_DB_v2.csv')

# %%
db.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 material   shape coat/functional group  \
# 0             0           0     SiO2  Sphere                  CTAB
# 1             1           1     SiO2  Sphere                  CTAB
# 2             2           2     SiO2  Sphere                  CTAB
# 3             3           3     SiO2  Sphere                  CTAB
# 4             4           4     SiO2  Sphere                  CTAB
#
#   synthesismethod surface charge  size in medium (nm)  zeta in medium (mV)  \
# 0   Precipitation       Negative                90.09                  NaN
# 1   Precipitation       Negative                90.09                  NaN
# 2   Precipitation       Negative                90.09                  NaN
# 3   Precipitation       Negative                90.09                  NaN
# 4   Precipitation       Negative                90.09                  NaN
#
#    no of cells (cells/well)  ... test   test indicator viability (%)  \
# ...

# %%
del db['Unnamed: 0.1']
del db['Unnamed: 0']

# %%
db.describe()
# Out:
#        size in medium (nm)  zeta in medium (mV)  no of cells (cells/well)  \
# count          1719.000000          1322.000000               3044.000000
# mean            197.970221           -12.503079              51530.814717
# std             191.625450            15.415578             123987.106055
# min               7.600000           -63.310000                300.000000
# 25%              77.000000           -20.670000              10000.000000
# 50%             142.110000           -11.600000              10000.000000
# 75%             230.000000            -8.200000              50000.000000
# max            1262.330000            48.600000            1000000.000000
#
#          time (hr)  concentration (ug/ml)  viability (%)  core size (nm)  \
# count  6107.000000            4220.000000    6601.000000     1066.000000
# mean     33.346815              80.487058      75.458086       40.193809
# std      23.844510             157.617455      31.430453       35.656944
# ...

# %%
db['norm by time+conc'] = db['time (hr)'] * db['concentration (ug/ml)']

# %%
db.plot(kind='scatter', x='Zeta potential (mV)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Zeta potential (mV)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='Hydrodynamic diameter (nm)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Hydrodynamic diameter (nm)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='concentration (ug/ml)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='concentration (ug/ml)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='size in medium (nm)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='size in medium (nm)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='zeta in medium (mV)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='zeta in medium (mV)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='core size (nm)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='core size (nm)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='surface area', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='surface area', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='Molecular weight (g/mol)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Molecular weight (g/mol)', ylabel='viability (%)'>

# %%
db['Zeta norm'] = db['Zeta potential (mV)'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='Zeta norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Zeta norm', ylabel='viability (%)'>

# %%
db['Zeta norm (log)'] = np.log10(db['Zeta norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='Zeta norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Zeta norm (log)', ylabel='viability (%)'>

# %%
db['Hydro norm'] = db['Hydrodynamic diameter (nm)'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='Hydro norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Hydro norm', ylabel='viability (%)'>

# %%
db['Hydro norm (log)'] = np.log10(db['Hydro norm'])

# %%
db.plot(kind='scatter', x='Hydro norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Hydro norm (log)', ylabel='viability (%)'>

# %%
db['size med norm'] = db['size in medium (nm)'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='size med norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='size med norm', ylabel='viability (%)'>

# %%
db['size med norm (log)'] = np.log10(db['size med norm'])

# %%
db.plot(kind='scatter', x='size med norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='size med norm (log)', ylabel='viability (%)'>

# %%
db['zeta med norm'] = db['zeta in medium (mV)'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='zeta med norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='zeta med norm', ylabel='viability (%)'>

# %%
db['zeta med norm (log)'] = np.log10(db['zeta med norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='zeta med norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='zeta med norm (log)', ylabel='viability (%)'>

# %%
db['surf norm'] = db['surface area'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='surf norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='surf norm', ylabel='viability (%)'>

# %%
db['surf norm (log)'] = np.log10(db['surf norm'])

# %%
db.plot(kind='scatter', x='surf norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='surf norm (log)', ylabel='viability (%)'>

# %%
db['mol wt norm'] = db['Molecular weight (g/mol)'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='mol wt norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='mol wt norm', ylabel='viability (%)'>

# %%
db['mol wt norm (log)'] = np.log10(db['mol wt norm'])

# %%
db.plot(kind='scatter', x='mol wt norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='mol wt norm (log)', ylabel='viability (%)'>

# %%
db['Zeta/Diam norm'] = db['Zeta potential (mV)'] / (db['Hydrodynamic diameter (nm)'] * db['norm by time+conc'])

# %%
db.plot(kind='scatter', x='Zeta/Diam norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Zeta/Diam norm', ylabel='viability (%)'>

# %%
db['Zeta/Diam norm (log)'] = np.log10(db['Zeta/Diam norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='Zeta/Diam norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='Zeta/Diam norm (log)', ylabel='viability (%)'>

# %%
db['zeta/surf norm'] = db['Zeta potential (mV)'] / (db['surface area'] * db['norm by time+conc'])

# %%
db.plot(kind='scatter', x='zeta/surf norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='zeta/surf norm', ylabel='viability (%)'>

# %%
db['zeta/surf norm (log)'] = np.log10(db['zeta/surf norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='zeta/surf norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='zeta/surf norm (log)', ylabel='viability (%)'>

# %%
db['zeta/(hydro*surf) norm'] = db['Zeta potential (mV)'] / (db['Hydrodynamic diameter (nm)'] * db['surface area'])

# %%
db['zeta/(hydro*surf) norm (log)'] = np.log10(db['zeta/(hydro*surf) norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='zeta/(hydro*surf) norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='zeta/(hydro*surf) norm (log)', ylabel='viability (%)'>

# %%
db['hydro/core'] = db['Hydrodynamic diameter (nm)'] / db['core size (nm)']

# %%
db.plot(kind='scatter', x='hydro/core', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='hydro/core', ylabel='viability (%)'>

# %%
db['hydro/core norm'] = db['hydro/core'] / db['norm by time+conc']

# %%
db.plot(kind='scatter', x='hydro/core norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='hydro/core norm', ylabel='viability (%)'>

# %%
db['hydro/core norm (log)'] = np.log10(db['hydro/core norm'])

# %%
db.plot(kind='scatter', x='hydro/core norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='hydro/core norm (log)', ylabel='viability (%)'>

# %%
db['ch per particle norm'] = db['Zeta potential (mV)'] / (db['hydro/core'] * db['norm by time+conc'])

# %%
db.plot(kind='scatter', x='ch per particle norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='ch per particle norm', ylabel='viability (%)'>

# %%
db['ch per particle norm (log)'] = np.log10(db['ch per particle norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='ch per particle norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='ch per particle norm (log)', ylabel='viability (%)'>

# %%
db['surf per particle norm'] = db['surface area'] / (db['hydro/core'] * db['norm by time+conc'])

# %%
db.plot(kind='scatter', x='surf per particle norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='surf per particle norm', ylabel='viability (%)'>

# %%
db['surf per particle norm (log)'] = np.log10(db['surf per particle norm'])

# %%
db.plot(kind='scatter', x='surf per particle norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='surf per particle norm (log)', ylabel='viability (%)'>

# %%
db['ch per surf per particle norm'] = db['Zeta potential (mV)'] / (db['surface area'] * db['hydro/core'] * db['norm by time+conc'])

# %%
db.plot(kind='scatter', x='ch per surf per particle norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='ch per surf per particle norm', ylabel='viability (%)'>

# %%
db['ch per surf per particle norm (log)'] = np.log10(db['ch per surf per particle norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='ch per surf per particle norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='ch per surf per particle norm (log)', ylabel='viability (%)'>

# %%
db['ch per moles norm'] = db['Zeta potential (mV)'] / (db['Molecular weight (g/mol)'] * db['norm by time+conc'])

# %%
db.plot(kind='scatter', x='ch per moles norm', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='ch per moles norm', ylabel='viability (%)'>

# %%
db['ch per moles norm (log)'] = np.log10(db['ch per moles norm'])
# Out:
# c:\projects\laboratory\interpreter\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
db.plot(kind='scatter', x='ch per moles norm (log)', y='viability (%)')
# Out:
# <AxesSubplot:xlabel='ch per moles norm (log)', ylabel='viability (%)'>

# %%
db.plot(kind='scatter', x='ch per moles norm (log)', y='Hydrodynamic diameter (nm)')
# Out:
# <AxesSubplot:xlabel='ch per moles norm (log)', ylabel='Hydrodynamic diameter (nm)'>

# %%
import matplotlib.pyplot as plt

f = plt.figure(figsize=(19, 15))
plt.matshow(db.corr(), fignum=f.number)
plt.yticks(range(db.select_dtypes(['number']).shape[1]), db.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
db.plot(kind='scatter', x='Zeta potential (mV)', y='zeta in medium (mV)')
# Out:
# <AxesSubplot:xlabel='Zeta potential (mV)', ylabel='zeta in medium (mV)'>

# %%
db.to_csv('Tox_DB_v2.csv')
